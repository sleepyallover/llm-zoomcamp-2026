# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
documents=load_faq_data()
index=build_index(documents)

# %%
assistant = RAGBase(index, openai_client)
assistant.rag("What can I expect from this class?")
# Out:
# "From this class, you can expect to learn about various topics related to large language models (LLMs) and their applications, including:\n\n1. **Foundational Knowledge**: You'll gain an introduction to LLMs and techniques like retrieval-augmented generation (RAG).\n   \n2. **Practical Skills**: The course includes hands-on homework assignments where you can start learning and submitting work even without an official confirmation of registration.\n   \n3. **Technical Troubleshooting**: You'll encounter and solve common issues, particularly in using tools like Jupyter and asyncio.\n\n4. **Embedding and Vector Search**: Learn how to convert non-numerical data into numerical data and apply cosine similarity to measure data relationships.\n\n5. **Project Submission**: You'll participate in a capstone project with the chance to submit and improve your work.\n\n6. **Tools and Technologies**: Familiarize yourself with tools like Docker and data ingestion techniques.\n\nOverall, expect a blend of theoretical knowledge and practical experience in AI-related technologies."
